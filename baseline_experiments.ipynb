# %% [markdown]
# # Baseline

# %% [markdown]
# ## Общая инициализация
# Нужно выполнить в самом начале независимо от дальнейших действий

# %% [markdown]
# ### Путь к каталогу, в котором лежит датасет
# датасет представлен файлом `train.csv` и папкой `train`

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce GTX 1080 Ti (UUID: GPU-6ecd5bbd-e1bc-e7f2-f73a-3c157df58ab0)

# %%
base_folder = "/home/ext-zorkina-a@ad.speechpro.com/ZorkinaAnastasia/audio_analytics"

# %% [markdown]
# #### Инициализация путей

# %%
import os.path as path

# %%
# path
train_folder = path.join(base_folder, "audio_train/train")
train_csv = path.join(base_folder, "train.csv")
train_pickle = path.join(base_folder, "train.pickle")
labels_pickle = path.join(base_folder, "labels.pickle")

# %% [markdown]
# ### Изучение аудиофайлов датасета

# %%
import os
import random

import librosa
import librosa.feature as F

import numpy as np

import matplotlib.pyplot as plt

from IPython.display import Audio

# %%
# random filename from dir
files = os.listdir(train_folder)
filename = random.choice(files)
filename
# Out:
# '165c0347ce92ca3e67ee.wav'

# %% [markdown]
# #### Спектрограмма

# %%
# spectrogram parameters
sample_rate = 11025

# %%
print (np.__version__)
# Out:
# 1.23.5

# %%
wav_data, sr = librosa.load(os.path.join(train_folder, filename), sr=sample_rate)

fig, (ax_top, ax_bottom) = plt.subplots(nrows=2, ncols=1, figsize=(10, 8), sharex=True)
cmap = "viridis"

# draw linear-frequency spectrogram
hop_length = 512
wav_data_db = librosa.amplitude_to_db(
    np.abs(librosa.stft(wav_data, hop_length=hop_length)),
    ref=np.max
)
img1 = librosa.display.specshow(
    wav_data_db,
    sr=sr,
    hop_length=hop_length,
    ax=ax_top,
    x_axis='time',
    y_axis='linear',
    cmap=cmap,
)
ax_top.set(title='Linear-frequency power spectrogram')
ax_top.label_outer()

# draw log-frequency spectrogram
hop_length = 1024
wav_data_db = librosa.amplitude_to_db(
    np.abs(librosa.stft(wav_data, hop_length=hop_length)),
    ref=np.max
)
img2 = librosa.display.specshow(
    wav_data_db,
    sr=sr,
    hop_length=hop_length,
    ax=ax_bottom,
    x_axis='time',
    y_axis='log',
    cmap=cmap,
)
ax_bottom.set(title='Log-frequency power spectrogram')
ax_bottom.label_outer()

fig.colorbar(img1, ax=[ax_top, ax_bottom], format="%+2.f dB")
plt.show()

display(Audio(wav_data, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Mel-спектрограмма

# %%
# melspectrogram parameters
sample_rate = 11025
n_fft = 1024
overlap = 4
hop_length = n_fft // overlap
n_mels = 64

# %%
wav_data, sr = librosa.load(os.path.join(train_folder, filename), sr=sample_rate)

mel_spec = F.melspectrogram(
    y=wav_data,
    n_fft=n_fft,
    hop_length=hop_length,
    n_mels=n_mels, 
    fmax=sample_rate // 2
)

fig, (ax_top, ax_bottom) = plt.subplots(nrows=2, ncols=1, figsize=(10, 8), sharex=True)
cmap = "viridis"

img1 = librosa.display.specshow(
    mel_spec,
    sr=sr,
    fmax=sr // 2,
    ax=ax_top,
    x_axis='time',
    y_axis='mel',
    cmap=cmap,
)
ax_top.set(title='Мелспектрограмма')
ax_top.label_outer()

D = librosa.power_to_db(mel_spec, ref=np.max)
img2 = librosa.display.specshow(
    D,
    sr=sr,
    fmax=sr // 2,
    ax=ax_bottom,
    x_axis='time',
    y_axis='mel',
    cmap=cmap,
)
ax_bottom.set(title='Логарифм мелспектрограммы')
ax_bottom.label_outer()

fig.colorbar(img1, ax=[ax_top, ax_bottom], format="%+2.f dB")
plt.show()

display(Audio(wav_data, rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Извлечение признаков

# %%
import os
import pickle
import pandas as pd
from enum import Enum
from typing import NoReturn, Optional

from tqdm import tqdm

#import pandas as pd
import numpy as np

import librosa
import librosa.feature as F


class SetType(Enum):
    """Set type"""
    TRAIN = 1
    TEST  = 2
    DEV   = 3


def extract_log_mel_feats(set_type:SetType, path_to_csv:str, path_to_files:str,
                          out_path:str, labels_pickle:str, sr:Optional[int], n_fft:int,
                          hop_length:int, n_mels:int):
    """
    Extract features from given files and store them in binary format.

    :param set_type: set tyle
    :param path_to_csv: path to loaded csv
    :param path_to_files: path to loaded data
    :param out_path: path to store extracted features
    :param labels_pickle: path to store labels dictionary
    :param sr: input files sample rate
    :param n_fft: size of fft window
    :param hop_length: hop size
    :param n_mels: number of mel band

    :return:
    """
    if set_type not in [SetType.TRAIN, SetType.TEST]:
        raise Exception(f'Such set type not supported: {set_type}')

    feats = []

    if set_type == SetType.TRAIN:
        meta = pd.read_csv(path_to_csv, skiprows=1, names=['fname', 'label'])

        file_names = list(meta['fname'])
        n_files = len(file_names)
        labels = list(meta['label'])

        uniq_labels = np.sort(np.unique(labels))
        label_to_id = {label: i for i, label in enumerate(uniq_labels)}

        print('Total files:', n_files)

        for i, (file_name, label) in tqdm(enumerate(zip(file_names, labels))):
            wav_data, sr = librosa.load(os.path.join(path_to_files, file_name), sr=sr)
            mel_spec = F.melspectrogram(
                y=wav_data,
                n_fft=n_fft,
                hop_length=hop_length,
                n_mels=n_mels,
                fmax=sr // 2
            )
            log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)
            feats.append({
                'fname': file_name,
                'feature': log_mel_spec,
                'label_id': label_to_id[label]
            })

        pickle.dump(feats, open(out_path, 'wb'))
        pickle.dump(label_to_id, open(labels_pickle, 'wb'))
        return label_to_id
    else:
        for i, file_name in tqdm(enumerate(os.listdir(path_to_files))):
            wav_data, sr = librosa.load(os.path.join(path_to_files, file_name), sr=sr)
            if len(wav_data) == 0:
                wav_data = np.zeros(sr)
            mel_spec = F.melspectrogram(
                y=wav_data,
                n_fft=n_fft,
                hop_length=hop_length,
                n_mels=n_mels,
                fmax=sr // 2
            )
            log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)
            feats.append({
                'fname': file_name,
                'feature': log_mel_spec,
            })

        pickle.dump(feats, open(out_path, 'wb'))
        return

# %%
# feature extraction parameters
sample_rate = 11025
n_fft = 1024
overlap = 4
hop_length = n_fft // overlap
n_mels = 64

# %%
# extract features and store to `train_pickle` extracted features
label_to_id = extract_log_mel_feats(
    SetType.TRAIN,
    train_csv, 
    train_folder, 
    train_pickle,
    labels_pickle,
    sample_rate, 
    n_fft, 
    hop_length, 
    n_mels
)

id_to_label = [label for label, i in label_to_id.items()]
# Out:
# Total files: 5683
# 5683it [01:08, 82.46it/s]

# %% [markdown]
# ## Алгоритм детектирования

# %% [markdown]
# ### Подготовительный этап

# %%
from typing import NoReturn
from pprint import pprint
import random

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
device = device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
cpu_count = os.cpu_count()

num_workers = cpu_count if device == "cpu" else 0
num_workers, cpu_count
# Out:
# (0, 4)

# %% [markdown]
# #### Добиваемся максимальной воспроизводимости
# Согласно данному мануалу: https://pytorch.org/docs/stable/notes/randomness.html

# %%
def set_random_state(random_state:int=0) -> NoReturn:
    """Initialize random generators.

    Parameters
    ==========
    random_state : int = 0
        Determines random number generation for centroid initialization.
        Use an int to make the randomness deterministic.
    """
    torch.manual_seed(random_state)
    random.seed(random_state)
    np.random.seed(random_state)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(random_state)
        torch.cuda.manual_seed(random_state)

        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %%
random_state = 42

# %%
set_random_state(random_state)

# %%
torch.use_deterministic_algorithms(True)

# %%
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8
# %env PYTHONHASHSEED=42
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8
# env: PYTHONHASHSEED=42

# %% [markdown]
# ### Архитектура нейронной сети

# %%
class DummyNetwork(nn.Module):
    """Neural network base architecture"""
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=1,  out_channels=64, kernel_size=5, stride=(2, 2), device=device)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3, stride=(1, 1), device=device)
        self.conv3 = nn.Conv2d(in_channels=96, out_channels=64, kernel_size=3, stride=(1, 1), device=device)

        self.mp = nn.MaxPool2d(kernel_size=(2, 2), stride=(1, 1))
        
        self.dropout1 = nn.Dropout(p=0.3)
        self.dropout2 = nn.Dropout(p=0.3)
        self.dropout3 = nn.Dropout(p=0.3)
        
        self.bn1 = nn.BatchNorm2d(num_features=64, device=device)
        self.bn2 = nn.BatchNorm2d(num_features=96, device=device)
        self.bn3 = nn.BatchNorm2d(num_features=64, device=device)

        self.flat = nn.Flatten()

        # 33856 - должно соответствовать форме self.flat
        self.fc1 = nn.Linear(80960, 41, device=device)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout1(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout2(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout3(x)

        x = self.flat(x)

        # здесь можно еще добавить полносвязный слой или слои
        x = self.fc1(x)

        return x

# %%
set_random_state(random_state) # try to run this cell several times
                               # then comment this line and run it several times again
                               # * pay attention at tensors values

# random 4D tensor
random_input = torch.randn(1, 1, 64, 64, requires_grad=True, device=device)

print(f"Исходный тензор {list(random_input.shape)}:")
pprint(random_input)

# create neural network instance
network = DummyNetwork()

# pass data throught the neural network
output = network(random_input)

print(f"\nТензор на выходе нейронной сети {list(output.shape)}:")
pprint(output)
# Out:
# Исходный тензор [1, 1, 64, 64]:
# tensor([[[[ 0.1940,  2.1614, -0.1721,  ..., -0.8146,  0.2502, -0.4273],
#           [ 1.1044, -1.1028,  0.5543,  ..., -1.2072, -0.2438, -0.6784],
#           [ 0.1973,  0.9782, -0.0287,  ..., -0.1266, -0.4321, -1.3943],
#           ...,
#           [-1.1998,  0.5818, -0.7198,  ..., -0.6079, -1.8145,  0.2807],
#           [-0.0970,  0.9319, -0.4393,  ..., -0.1155, -0.0528,  1.1175],
#           [ 3.0098,  1.3304, -1.1632,  ...,  0.1124,  0.2769, -1.2535]]]],
#        device='cuda:0', requires_grad=True)
#
# Тензор на выходе нейронной сети [1, 41]:
# tensor([[ 0.2344, -0.6144,  0.6058, -0.3985,  0.7906,  0.3616, -0.4576,  0.2380,
#           0.7785,  0.3695, -0.8342,  0.3495, -0.4769, -0.4046, -0.0396, -0.2823,
#          -0.1911,  1.1767,  0.3452,  0.7532,  0.3899,  0.5658,  0.7681,  1.4253,
#           0.2472,  0.5790, -0.6740,  0.1327, -1.2493,  0.3957,  1.1425,  0.0422,
#          -0.1789, -0.0786, -0.4913,  0.7336,  0.1984,  0.0233,  0.5368, -0.2680,
#           0.4194]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# ### Шаг оптимизации

# %%
import torch.optim as optim

# %%
set_random_state(random_state)


# choose loss function
criterion = nn.CrossEntropyLoss()

# choose and tune optimizer
optimizer = optim.SGD(network.parameters(), lr=0.001)
optimizer.zero_grad()

random_input = torch.randn(3, 1, 64, 64, requires_grad=True, device=device)
print(f"Тензор на входе сети {list(random_input.shape)}:")
pprint(random_input)

output = network(random_input)
print(f"\nТензор на выходе сети {list(output.shape)}:")
pprint(output)

target = torch.randint(5, (3,), dtype=torch.long, device=device)
print(f"\nТензор с целевыми значениями {list(target.shape)}:")
pprint(target)

loss = criterion(output, target)
print("\nЗначение функции потерь:", loss.item())

# backpropagation
loss.backward()

# next step
optimizer.step()
# Out:
# Тензор на входе сети [3, 1, 64, 64]:
# tensor([[[[ 0.1940,  2.1614, -0.1721,  ..., -0.8146,  0.2502, -0.4273],
#           [ 1.1044, -1.1028,  0.5543,  ..., -1.2072, -0.2438, -0.6784],
#           [ 0.1973,  0.9782, -0.0287,  ..., -0.1266, -0.4321, -1.3943],
#           ...,
#           [-1.1998,  0.5818, -0.7198,  ..., -0.6079, -1.8145,  0.2807],
#           [-0.0970,  0.9319, -0.4393,  ..., -0.1155, -0.0528,  1.1175],
#           [ 3.0098,  1.3304, -1.1632,  ...,  0.1124,  0.2769, -1.2535]]],
#
#
#         [[[ 1.1346, -0.6329, -0.9147,  ..., -1.5122, -1.1374,  0.7628],
#           [ 0.9661, -0.0587, -0.2129,  ...,  1.2377,  0.5842,  1.6728],
#           [ 0.7942,  0.3131, -0.3607,  ...,  0.1261, -0.1309,  2.0342],
#           ...,
#           [-0.3319,  0.8590,  0.7535,  ..., -1.2910, -0.3644,  0.9805],
#           [-0.5130,  0.6719, -0.1551,  ..., -0.4551, -0.1417, -1.2772],
#           [-0.4063,  0.0820,  0.8311,  ..., -1.0449,  1.5397, -2.0042]]],
#
#
#         [[[-0.5852, -0.9346,  0.9684,  ...,  0.5966, -1.6748,  1.7517],
#           [-0.5635,  0.6796, -0.0035,  ..., -0.7158,  0.6009, -0.1343],
#           [-0.0884,  1.5620, -2.4534,  ..., -0.3368, -1.8224, -1.3638],
#           ...,
#           [ 0.2365,  1.0833,  0.7093,  ..., -1.6241, -1.9040, -1.1110],
#           [-1.3202, -1.2294, -0.9519,  ..., -0.6687,  1.0752, -1.1125],
#           [-2.2164,  1.4685,  0.3879,  ...,  0.0506, -0.5426,  0.0125]]]],
#        device='cuda:0', requires_grad=True)
#
# Тензор на выходе сети [3, 41]:
# tensor([[-5.0391e-01,  8.5933e-02,  7.3682e-01,  1.6039e-01,  1.7498e-01,
#          -4.5474e-02,  2.7147e-01, -1.3097e-01, -5.3707e-01,  9.6178e-01,
#          -1.1731e+00,  3.4392e-01,  5.1085e-02,  7.5589e-02,  1.5090e+00,
#          -8.9557e-01, -5.8934e-01, -3.6557e-02, -1.7468e-01,  4.6798e-01,
#           1.0493e+00,  3.8524e-01,  1.1131e+00,  6.0876e-01,  1.6636e+00,
#           5.1913e-01, -6.2665e-01,  5.0962e-01, -8.8975e-01, -6.5094e-01,
#           1.2589e+00, -5.7999e-01, -1.0564e+00,  2.0207e-01, -3.3130e-02,
#           3.8991e-01,  2.1522e-01, -1.2566e+00, -3.1890e-02,  6.7948e-01,
#           1.2762e+00],
#         [-5.8484e-01,  6.4897e-01,  8.2982e-01,  2.8465e-01,  7.7763e-01,
#          -2.5498e-01,  6.3611e-01,  2.2102e-01,  1.3456e-01, -1.7015e-01,
#          -1.7187e+00,  8.9910e-01, -8.5991e-01, -8.5459e-01,  7.6457e-01,
#          -1.3986e+00, -4.4610e-01,  3.4483e-02,  2.3172e-01, -1.8529e-01,
#           5.9758e-01,  1.2717e+00,  5.3588e-02, -6.8962e-01,  1.1592e+00,
#          -2.7743e-01,  2.5488e-01,  5.0696e-01,  3.2993e-01, -3.0599e-01,
#           6.2819e-01,  1.3540e+00,  5.9554e-01,  9.7573e-01,  9.7368e-02,
#           4.1190e-01,  2.0298e+00, -1.6083e-01,  2.1626e-01, -6.8058e-01,
#           7.7877e-01],
#         [-8.2355e-02,  3.3948e-01,  2.4356e-02, -3.7845e-02,  4.8602e-01,
#           1.3963e+00,  8.4817e-01,  1.4328e-01,  1.6276e+00, -3.9176e-01,
#          -2.5391e-01,  7.0460e-01, -1.0299e+00, -1.6936e-01,  7.0029e-01,
#          -9.5031e-01, -4.0257e-02,  6.8487e-01,  1.1605e-01,  1.1088e-02,
#           7.4735e-01, -2.9412e-01,  8.3310e-01, -8.3561e-01,  5.2820e-01,
#           3.1684e-01,  2.0368e-01,  1.4353e-03,  1.2440e-01, -1.8453e+00,
#           1.1973e+00,  5.7669e-02, -1.0304e-01,  6.1367e-01,  5.4281e-01,
#          -1.1514e-01,  8.2806e-01, -4.7802e-01, -3.4996e-01, -6.0413e-01,
#          -7.2808e-02]], device='cuda:0', grad_fn=<AddmmBackward0>)
#
# Тензор с целевыми значениями [3]:
# tensor([0, 1, 1], device='cuda:0')
#
# Значение функции потерь: 3.9502735137939453

# %% [markdown]
# ### Обучение нейронной сети

# %% [markdown]
# #### Загрузка ранее извлеченных признаков и подготовка данных для обучения

# %%
import pickle
import copy

# %%
train_data = pickle.load(open(train_pickle, "rb"))

label_to_id = pickle.load(open(labels_pickle, "rb"))
id_to_label = [label for label, i in label_to_id.items()]

# %%
def prepare_shape(feature):
    tmp = feature
    N = 64*2 # размер во времени (можно увеличить, должно стать лучше)
    while tmp.shape[1] < N:
        # можно попробовать сделать np.pad для коротких файлов, вместо повторения до необходимой длины
        tmp = np.hstack((tmp, tmp))
        # tmp = np.hstack((tmp, np.zeros_like(tmp)))
    # случайный сдвиг должен улучшить результат (для этого нужно функцию перенести в EventDetectionDataset)
    tmp = tmp[np.newaxis, :, :N]
    return tmp

# %%
# можно улучшить, используя сбалансированное валидационное множество
# гуглить stratified train test split sklearn
validation_set_size = 800

x_val = []
y_val = []

x_tr = []
y_tr = []

for i, row in enumerate(train_data):
    #feature = prepare_shape(row['feature'])
    feature = row['feature']
    if i < validation_set_size:
        x_val.append(feature)
        y_val.append(row['label_id'])
    else:
        x_tr.append(feature)
        y_tr.append(row['label_id'])

# %%
from sklearn.model_selection import train_test_split

x = []
y = []

for i, row in enumerate(train_data):
        x.append(row['feature'])
        y.append(row['label_id'])

x_tr, x_val, y_tr, y_val = train_test_split(x, y, test_size=800, random_state=random_state, stratify=y)

# %%
x_val = np.asarray(x_val)
x_tr = np.asarray(x_tr)

y_val = np.asarray(y_val)
y_tr = np.asarray(y_tr)

print(f"""
Train set:
    x.shape: {x_tr.shape}
    y.shape: {y_tr.shape}

Validation set:
    x.shape: {x_val.shape}
    y.shape: {y_val.shape}
"""

# %%
from torch.utils.data import Dataset

# %%
class EventDetectionDataset(Dataset):
    def __init__(self, x, y=None, device="cpu"):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        # добавить сюда prepare_shape()
        
        if self.y is not None:
            return \
                torch.tensor(self.x[idx], device=device),\
                torch.tensor(self.y[idx], device=device)

        return torch.tensor(self.x[idx], device=device)

# %%
class EventDetectionDataset(Dataset):
    def __init__(self, x, y=None, device="cpu"):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def prepare_shape(self, feature):
        tmp = copy.deepcopy(feature)
        N = 64*2 # размер во времени (можно увеличить, должно стать лучше)
        while tmp.shape[1] < N:
            # можно попробовать сделать np.pad для коротких файлов, вместо повторения до необходимой длины
            tmp = np.hstack((tmp, tmp))
            # tmp = np.hstack((tmp, np.zeros_like(tmp)))
        # случайный сдвиг должен улучшить результат (для этого нужно функцию перенести в EventDetectionDataset)
        start = np.random.randint(0, tmp.shape[1] - N + 1)
        tmp = tmp[np.newaxis, :, start:start + N]
        return tmp
    
    def __getitem__(self, idx):
        # добавить сюда prepare_shape()
        x = self.prepare_shape(self.x[idx])
        
        if self.y is not None:
            return \
                torch.tensor(x, device=device),\
                torch.tensor(self.y[idx], device=device)

        return torch.tensor(x, device=device)

# %%
train_dset = EventDetectionDataset(x_tr, y_tr, device=device)
val_dset = EventDetectionDataset(x_val, y_val, device=device)

# %%
set_random_state(random_state)

sample_x, sample_y = random.choice(val_dset)

sample_y.item(), id_to_label[sample_y]
# Out:
# (10, 'Cough')

# %%
val_dset[10][0].shape
# Out:
# torch.Size([1, 64, 128])

# %%
import librosa
import matplotlib.pyplot as plt

# %%
sample_rate = 11025

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
cmap = "viridis"

img = librosa.display.specshow(
    sample_x[0].numpy(force=True),
    sr=sample_rate,
    fmax=sample_rate // 2,
    ax=ax,
    x_axis='time',
    y_axis='mel',
    cmap=cmap,
)
ax.set(title='Мелспектрограмма')
ax.label_outer()

fig.colorbar(img, ax=ax, format="%+2.f dB")
plt.tight_layout()
plt.show()

# %%
from torch.utils.data import DataLoader

# %%
train_loader = DataLoader(train_dset, batch_size=41, shuffle=True, num_workers=num_workers)
val_loader = DataLoader(val_dset, batch_size=41, shuffle=False, num_workers=num_workers)

# %%
import time
from sklearn.metrics import accuracy_score

# %%
start_time = time.time()

n_epoch = 70

set_random_state(random_state)

criterion = nn.CrossEntropyLoss()
network = DummyNetwork()

# можно попробовать другой optimizer, тоже считается улучшением
#optimizer = optim.SGD(network.parameters(), lr=0.001)
optimizer = optim.Adam(network.parameters(), lr=0.001)

train_loss = []
val_loss = []

train_acc = []
val_acc = []

for e in range(n_epoch):
    print(f'epoch #{e+1}')

    # train
    loss_list = []
    outputs = []
    targets = []
    for i_batch, sample_batched in enumerate(train_loader):
        x, y = sample_batched
        optimizer.zero_grad()

        output = network(x)
        outputs.append(output.argmax(axis=1))

        target = y
        targets.append(target)

        loss = criterion(output, target.long())
        loss_list.append(loss.item())
        loss.backward()
        optimizer.step()

    y_true = torch.hstack(targets).numpy(force=True)
    y_pred = torch.hstack(outputs).numpy(force=True)
    acc = accuracy_score(y_true, y_pred)

    train_loss.append(np.mean(loss_list))
    train_acc.append(acc)

    print(f'[train] mean loss: {train_loss[-1]}')
    print(f'[train] accuracy:  {acc}')

    loss_list = []
    outputs = []
    targets = []
    with torch.no_grad():
        for i_batch, sample_batched in enumerate(val_loader):
            x, y = sample_batched
            #optimizer.zero_grad()

            output = network(x)
            outputs.append(output.argmax(axis=1))

            target = y
            targets.append(target)

            loss = criterion(output, target.long())
            loss_list.append(loss.item())
            #loss.backward()
            #optimizer.step()

        y_true = torch.hstack(targets).numpy(force=True)
        y_pred = torch.hstack(outputs).numpy(force=True)
        acc = accuracy_score(y_true, y_pred)

        val_loss.append(np.mean(loss_list))
        val_acc.append(acc)
        
        print(f'[val] mean loss:   {val_loss[-1]}')
        print(f'[val] accuracy:    {acc}', end="\n\n")

print(f"Execution time: {(time.time() - start_time):.2f} seconds")
# Out:
# epoch #1
# [train] mean loss: 27.378235642115275
# [train] accuracy:  0.10137210731107925
# [val] mean loss:   14.969408082962037
# [val] accuracy:    0.155
#
# epoch #2
# [train] mean loss: 13.22365738550822
# [train] accuracy:  0.15809952897808724
# [val] mean loss:   10.534504318237305
# [val] accuracy:    0.165
#
# epoch #3
# [train] mean loss: 9.818779889742533
# [train] accuracy:  0.19660045054269917
# [val] mean loss:   9.952203154563904
# [val] accuracy:    0.1375
#
# epoch #4
# [train] mean loss: 6.933013925949733
# [train] accuracy:  0.23059594511570755
# [val] mean loss:   5.91222106218338
# [val] accuracy:    0.1725
#
# epoch #5
# [train] mean loss: 4.797912053267161
# [train] accuracy:  0.27032561949621137
# [val] mean loss:   4.175190401077271
# [val] accuracy:    0.255
#
# epoch #6
# [train] mean loss: 3.4621797760327655
# [train] accuracy:  0.32131886135572396
# [val] mean loss:   3.109856426715851
# [val] accuracy:    0.33875
#
# epoch #7
# [train] mean loss: 2.904118897517522
# [train] accuracy:  0.3626868728240836
# [val] mean loss:   2.651928836107254
# [val] accuracy:    0.355
#
# epoch #8
# [train] mean loss: 2.532426279783249
# [train] accuracy:  0.3893098505017407
# [val] mean loss:   2.38749138712883
# [val] accuracy:    0.375
#
# epoch #9
# [train] mean loss: 2.227835609515508
# [train] accuracy:  0.4280155642023346
# [val] mean loss:   2.360640877485275
# [val] accuracy:    0.4025
#
# epoch #10
# [train] mean loss: 2.04350651204586
# [train] accuracy:  0.45074749129633424
# [val] mean loss:   2.0940010845661163
# [val] accuracy:    0.445
#
# epoch #11
# [train] mean loss: 1.8874575008948644
# [train] accuracy:  0.47573213188613556
# [val] mean loss:   2.0586078643798826
# [val] accuracy:    0.445
#
# epoch #12
# [train] mean loss: 1.905840267241001
# [train] accuracy:  0.49457300839647755
# [val] mean loss:   2.030135041475296
# [val] accuracy:    0.455
#
# epoch #13
# [train] mean loss: 1.7175095150868098
# [train] accuracy:  0.528568502969486
# [val] mean loss:   1.9930281281471252
# [val] accuracy:    0.45875
#
# epoch #14
# [train] mean loss: 1.7142086217800776
# [train] accuracy:  0.5365553962727831
# [val] accuracy:    0.6025
#
# epoch #55
# [train] mean loss: 0.5744455834229787
# [train] accuracy:  0.8318656563587958
# [val] mean loss:   1.8902845442295075
# [val] accuracy:    0.6
#
# epoch #56
# [train] mean loss: 0.6173732409874598
# [train] accuracy:  0.8222404259676428
# [val] mean loss:   1.7766449809074403
# [val] accuracy:    0.585
#
# epoch #57
# [train] mean loss: 0.5820111940304439
# [train] accuracy:  0.8392381732541471
# [val] mean loss:   1.7486371606588365
# [val] accuracy:    0.5875
#
# epoch #58
# [train] mean loss: 0.6242332732925813
# [train] accuracy:  0.8240835551914807
# [val] mean loss:   1.998656874895096
# [val] accuracy:    0.5775
#
# epoch #59
# [train] mean loss: 0.5941933845480283
# [train] accuracy:  0.8287937743190662
# [val] mean loss:   1.8713156670331954
# [val] accuracy:    0.585
#
# epoch #60
# [train] mean loss: 0.5583637247482935
# [train] accuracy:  0.8457915216055704
# [val] mean loss:   1.9309366196393967
# [val] accuracy:    0.59375
#
# epoch #61
# [train] mean loss: 0.6607130202154319
# [train] accuracy:  0.8120008191685439
# [val] mean loss:   1.96953946352005
# [val] accuracy:    0.57875
#
# epoch #62
# [train] mean loss: 0.6129936871429285
# [train] accuracy:  0.8193733360638952
# [val] mean loss:   1.9326845288276673
# [val] accuracy:    0.58
#
# epoch #63
# [train] mean loss: 0.5748252209275961
# [train] accuracy:  0.8373950440303093
# [val] mean loss:   1.941716068983078
# [val] accuracy:    0.59625
#
# epoch #64
# [train] mean loss: 0.6908980733404557
# [train] accuracy:  0.811181650624616
# [val] mean loss:   2.04525183737278
# [val] accuracy:    0.5975
#
# epoch #65
# [train] mean loss: 0.5736410864939292
# [train] accuracy:  0.8410813024779848
# [val] mean loss:   2.073535090684891
# [val] accuracy:    0.58
#
# epoch #66
# [train] mean loss: 0.5716253827015559
# [train] accuracy:  0.8427196395658406
# [val] mean loss:   2.073816531896591
# [val] accuracy:    0.6025
#
# epoch #67
# [train] mean loss: 0.6429412297904491
# [train] accuracy:  0.8132295719844358
# [val] mean loss:   1.94002146422863
# [val] accuracy:    0.57125
#
# epoch #68
# [train] mean loss: 0.5870713748037815
# [train] accuracy:  0.8359614990784354
# [val] mean loss:   1.9440777957439423
# [val] accuracy:    0.605
#
# epoch #69
# [train] mean loss: 0.5189417927215497
# [train] accuracy:  0.8597173868523449
# [val] mean loss:   2.037400072813034
# [val] accuracy:    0.5875
#
# epoch #70
# [train] mean loss: 0.49881570860743524
# [train] accuracy:  0.8545975834527955
# [val] mean loss:   1.9810920000076293
# [val] accuracy:    0.59625
#
# Execution time: 181.20 seconds

# %%
def plot_curves():
    
    epochs = range(1, n_epoch+1)

    fig, (ax_top, ax_bottom) = plt.subplots(nrows=2, ncols=1, figsize=(10, 10), sharex=True)

    xticks = range(1, n_epoch+1, n_epoch // 10) if n_epoch > 10 else epochs

    # draw loss
    ax_top.plot(epochs, train_loss, 'r', label='train')
    ax_top.plot(epochs, val_loss, 'b', label='validation')

    ax_top.set(
        title='Loss',
        xlabel='Epoch number',
        ylabel='Loss value',
        ylim=[0, max(max(train_loss), max(val_loss)) + 1],
    )
    ax_top.legend(
        title="Выборка",
    )
    ax_top.grid()

    # draw accuracy
    ax_bottom.plot(epochs, train_acc, 'r', label='train')
    ax_bottom.plot(epochs, val_acc, 'b', label='validation')

    ax_bottom.set(
        title='Accuracy',
        xlabel='Epoch number',
        ylabel='Accuracy value',
        xticks=xticks,
        ylim=[0, 1],
    )
    ax_bottom.legend(
        title="Выборка",
    )
    ax_bottom.grid()

    fig.suptitle("Кривые обучения")

    plt.show()

# %%
plot_curves()

# %%
print(max(val_acc))
# Out:
# 0.495

# %% [markdown]
# ## Проведение экспериментов

# %% [markdown]
# **Теоретическая часть из лекции**

# %% [markdown]
# Что влияет на переобучение:
# - количество весов сети
# - размер обучающей выборки
#
# При переобучении на графике надлюдается следующая картина: начиная с некоторого момента train loss продолжает падать, при этом val loss начал расти

# %% [markdown]
# Что можно менять:
#
# 1. Этап извлечения параметров extract_log_mel_feats:
#    - sr, fft_size, hop (имеет смысл проанализировать типы событий, насколько высокая разрешающая способность по частотам нужна: посмотреть на плохо сработавшие события)
#    - n_mels (чем больше мел-фичей, тем больше весов нужно, что может быть не оптимально)
#
#
# 2. Стоит ли логарифмировать полученные фичи
#
#
# 3. Модель (параметры модели определяют количество обучаемых весов, что напрямую влияет на переобучение)
#
#
# 4. Параметры при обучении:
#    - выбор функции потерь (можно менять саму loss функцию, можно добавлять регуляризации)
#    - выбор оптимизатора и его параметров
#
#
# 5. Подготовка данных prepare_shape
#    - как и какого размера отрезаемм куски (первые, последние)
#    - padding (нули, повторения)
#    - можно добавить случайный сдвиг
#
#
# 6. Балансировка валидационного множества

# %% [markdown]
# Запуск с исходными параметрами

# %%
plot_curves()

# %% [markdown]
# Количество эпох обучения увеличено до 70, в целом картина не изменилась

# %%
plot_curves()

# %% [markdown]
# Попробуем поэкспериментировать с SGD и уменьшим learning rate до 0.0001. Кажется, что 70 эпох для такого шага мало

# %%
plot_curves()

# %% [markdown]
# Увеличили количество эпох до 100

# %%
plot_curves()

# %% [markdown]
# Результаты ожидаемые
#
# Изменим оптимизатор на Adam, learning rate = 0.001. Судя по графику loss модель ловит переобучение

# %%
plot_curves()

# %% [markdown]
# Попробуем подойти с другой стороны и увеличить количество секунд на котором обучаемся: будем брать в два раза больше отсчетов для обучения (N=128, optimizer оставляем Adam)

# %%
plot_curves()

# %% [markdown]
# Стало лучше. Попробуем не дублировать короткие файлы, а дополнять их нулями до нужной длины

# %%
plot_curves()

# %% [markdown]
# Дозаполнение нулями значительных изменений не дало, при этом все так же наблюдается характерная для переобучения картина.
#
# Попробуем добавить  случайный сдвиг. Теперь каждый раз для обучения будем брать не первые 2 или 4 секунды (что, в целом, было не очень оптимально с учетом того, что события могли содержаться в конце аудиозаписи и не попадать в выборку), а случайные. В теории, это должно улучшить результаты.

# %%
plot_curves()

# %% [markdown]
# Отлично! Это определенно самое удачное изменение из всех. Удалось достичь точности на валидации = 0.6. При этом где-то к 40 эпохе график выходит на плато.
#
# Возможно, результат можно сделать еще лучше, если изменить способ разбиения train/val на stratified чтобы соблюсти баланс классов в трейне и валидации.

# %%
plot_curves()

# %% [markdown]
# Каких-то значимых изменений это не дало, так что скорее всего изначально балансировка классов была примерно одинаковой

# %% [markdown]
# Таким образом наиболее значительными улучшениями оказались изменения на этапе подготовки данных для обучения: увеличение количества секунд в два раза и, самое существенное, выбор случайного куска для каждой записи. С учетом всех изменений удалось добиться повышения точности модели на валидации до 0.609
